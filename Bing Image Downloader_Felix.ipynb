# %%
from bing_image_downloader import downloader

# %%
downloader.download("natur", limit=50,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to C:\Users\felix\Documents\Untitled Folder\dataset\natur
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 51 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.bergreenphotography.com/wp-content/uploads/2017/07/import-140-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.fotocommunity.com/true-wilderness-a3a765d2-878e-4ee3-8bef-f0384ff9aac5.jpg?width=1000
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.bergreenphotography.com/wp-content/uploads/2017/05/adventure-wedding-photographer-01-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://macarologie.fr/wp-content/uploads/2018/02/islande-kai-gradert-99361-1024x576.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/ed/53/63/ed536328b8cbea286559496b3e8bab33.jpg
# [%] File Downloaded !
#
# ...
